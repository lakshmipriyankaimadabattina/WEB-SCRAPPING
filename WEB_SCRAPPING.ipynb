# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmipriyankaimadabattina/WEB-SCRAPPING/blob/main/WEB_SCRAPPING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Web scrapping
#
# Gudied by:R Raja Subramanian Sir
#
# Name: I.lakshmi Priyanka
#
# Section:B

# %%
from bs4 import BeautifulSoup
import requests
import csv
import pandas as pd

url = "https://www.swiggy.com/restaurants/ravi-tasty-foods-1st-lane-brindavan-gardens-guntur-87678"
p = requests.get(url)
soup = BeautifulSoup(p.content,'html.parser')
print(p)
content = soup.find_all('div', class_="_2wg_t")
fheader = ["Food_Name","Price"]

itemfull = []

for item in content:
  items = []
  Food_name = item.find('h3', class_="styles_itemNameText__3ZmZZ")
  price = item.find('div', class_="styles_itemPortionContainer__1u_tj")
  
  
  if(Food_name is not None):
    items.append(Food_name.text)
  else:
    items.append("Food_name is NA")
  if(price is not None):
    items.append(price.text)
  else:
    items.append("No Original Price")
  
  itemfull.append(items)

pd.DataFrame(itemfull).to_csv("food.csv",header=fheader)
# Out:
# <Response [200]>

# %%
data = pd.read_csv("food.csv")

# %%
data.head()
# Out:
#    Unnamed: 0                     Food_Name  Price
# 0           0                Veg Manchurian    130
# 1           1                     Paneer 65    200
# 2           2                 Chilli Paneer    200
# 3           3                    Chicken 65    250
# 4           4  Chicken Lollipop ( 5 pieces)    260

# %%
x = data.Food_Name
y = data.Price

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

plt.scatter(x,y,color='blue')
plt.title("Scatter plot")
plt.ylabel("oders")
plt.xticks(rotation='vertical')
plt.xlabel("item names")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(x,y,color="Blue")
plt.xlabel("item names")
plt.ylabel("oders")
plt.title("Line Plot")
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import matplotlib.pyplot as plt

plt.hist(x,color="purple")
plt.xlabel("item names")
plt.ylabel("oders")
plt.title("hotel paradise")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.stackplot(x,y, color = 'b')
plt.xlabel("item names")
plt.ylabel("oders")
plt.title("stack plot")
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.bar(x,y)
plt.show()

# %%
import plotly.graph_objects as go

# %%
fig = go.Figure(data=[go.Scatter(
    x = data.Food_Name, y = data.Price,
    mode='markers',
    marker=dict(
            color='LightSkyBlue',
            line=dict(
                color='MediumPurple',
                width=2
            )
        ),
    marker_size=[40, 60, 80, 100])
])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
